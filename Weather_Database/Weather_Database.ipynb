# %%
#import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
#Import request
import requests
#Import weather API Key.
from config import weather_api_key

# %%
#Starting URL for Weather map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
#Loop through all the cities in the list.
for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes.
    if (i %50==0 and i>=50):
        set_count +=1
        record_count = 1
    #Create endpoint URL with each city.
    city_url = url+ "&q=" + city.replace(" ","+")
        # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_descrip = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_weather_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | narsaq
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | alexandria
# Processing Record 7 of Set 1 | ancud
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | orlik
# Processing Record 10 of Set 1 | sao filipe
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | pitimbu
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | candido mota
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | jiwani
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | fairbanks
# Processing Record 21 of Set 1 | atbasar
# Processing Record 22 of Set 1 | khorramabad
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | faanui
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | uglekamensk
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | dakar
# Processing Record 29 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | saint george
# Processing Record 33 of Set 1 | klyuchi
# Processing Record 34 of Set 1 | brae
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | scarborough
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | geraldton
# Processing Record 44 of Set 1 | harper
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | peniche
# Processing Record 47 of Set 1 | bengkulu
# Processing Record 48 of Set 1 | pirgos
# Processing Record 49 of Set 1 | mahebourg
# Processing Record 50 of Set 1 | holguin
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | nuuk
# Processing Record 4 of Set 2 | nassjo
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | nsanje
# Processing Record 8 of Set 2 | miri
# Processing Record 9 of Set 2 | victoria
# Processing Record 10 of Set 2 | kidal
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | grindavik
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | luanda
# Processing Record 15 of Set 2 | koungheul
# Processing Record 16 of Set 2 | mildura
# Processing Record 17 of Set 2 | killybegs
# Processing Record 18 of Set 2 | lugovoy
# Processing Record 19 of Set 2 | poum
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | muroto
# Processing Record 22 of Set 2 | klaksvik
# Processing Record 23 of Set 2 | dunedin
# Processing Record 24 of Set 2 | sisimiut
# Processing Record 25 of Set 2 | roald
# Processing Record 26 of Set 2 | qaqortoq
# Processing Record 27 of Set 2 | cherskiy
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | wattegama
# Processing Record 30 of Set 2 | shingu
# Processing Record 31 of Set 2 | caravelas
# Processing Record 32 of Set 2 | bathsheba
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | kamyshlov
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | katsuura
# Processing Record 37 of Set 2 | khalkhal
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | souillac
# Processing Record 41 of Set 2 | xiongshi
# City not found. Skipping...
# Processing Record 42 of Set 2 | guantanamo
# Processing Record 43 of Set 2 | saint anthony
# Processing Record 44 of Set 2 | ahipara
# Processing Record 45 of Set 2 | constitucion
# Processing Record 46 of Set 2 | pierre
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | las juntas
# Processing Record 49 of Set 2 | cascais
# Processing Record 50 of Set 2 | de land
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 3 | tura
# Processing Record 4 of Set 3 | san cristobal
# Processing Record 5 of Set 3 | coihaique
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | bilma
# Processing Record 8 of Set 3 | anadyr
# Processing Record 9 of Set 3 | srandakan
# Processing Record 10 of Set 3 | basco
# Processing Record 11 of Set 3 | coahuayana
# Processing Record 12 of Set 3 | caluquembe
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | barrow
# Processing Record 15 of Set 3 | manzanillo
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | mazamari
# Processing Record 18 of Set 3 | ingham
# Processing Record 19 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 3 | acarau
# Processing Record 21 of Set 3 | esperance
# Processing Record 22 of Set 3 | manado
# Processing Record 23 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 3 | pangnirtung
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | cayenne
# Processing Record 27 of Set 3 | hamilton
# Processing Record 28 of Set 3 | taltal
# Processing Record 29 of Set 3 | shushtar
# Processing Record 30 of Set 3 | morant bay
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | den helder
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | torbay
# Processing Record 35 of Set 3 | east london
# Processing Record 36 of Set 3 | rosarito
# Processing Record 37 of Set 3 | kalmunai
# Processing Record 38 of Set 3 | chokurdakh
# Processing Record 39 of Set 3 | yalutorovsk
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | alofi
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | changying
# Processing Record 45 of Set 3 | plettenberg bay
# Processing Record 46 of Set 3 | bluff
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | broken hill
# Processing Record 49 of Set 3 | balsas
# Processing Record 50 of Set 3 | kang
# Processing Record 1 of Set 4 | usinsk
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | benghazi
# Processing Record 4 of Set 4 | beringovskiy
# Processing Record 5 of Set 4 | qaanaaq
# Processing Record 6 of Set 4 | palmer
# Processing Record 7 of Set 4 | kenai
# Processing Record 8 of Set 4 | ust-koksa
# Processing Record 9 of Set 4 | linxia
# Processing Record 10 of Set 4 | pacific grove
# Processing Record 11 of Set 4 | honiara
# Processing Record 12 of Set 4 | dumabato
# Processing Record 13 of Set 4 | fort nelson
# Processing Record 14 of Set 4 | mongo
# Processing Record 15 of Set 4 | volchanets
# Processing Record 16 of Set 4 | touros
# Processing Record 17 of Set 4 | praia da vitoria
# Processing Record 18 of Set 4 | teahupoo
# Processing Record 19 of Set 4 | ulagan
# Processing Record 20 of Set 4 | berlevag
# Processing Record 21 of Set 4 | teya
# Processing Record 22 of Set 4 | xichang
# Processing Record 23 of Set 4 | guerrero negro
# Processing Record 24 of Set 4 | san quintin
# Processing Record 25 of Set 4 | komsomolskiy
# Processing Record 26 of Set 4 | bismarck
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | medicine hat
# Processing Record 29 of Set 4 | itarema
# Processing Record 30 of Set 4 | birao
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | ponta do sol
# Processing Record 33 of Set 4 | tazovskiy
# Processing Record 34 of Set 4 | novoagansk
# Processing Record 35 of Set 4 | lorengau
# Processing Record 36 of Set 4 | talnakh
# Processing Record 37 of Set 4 | port-gentil
# Processing Record 38 of Set 4 | hofn
# Processing Record 39 of Set 4 | bilibino
# Processing Record 40 of Set 4 | ilulissat
# Processing Record 41 of Set 4 | little current
# Processing Record 42 of Set 4 | hasaki
# Processing Record 43 of Set 4 | gimli
# Processing Record 44 of Set 4 | nantucket
# Processing Record 45 of Set 4 | houston
# Processing Record 46 of Set 4 | isla mujeres
# Processing Record 47 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 4 | sechura
# Processing Record 49 of Set 4 | gigmoto
# Processing Record 50 of Set 4 | strezhevoy
# Processing Record 1 of Set 5 | quang ngai
# Processing Record 2 of Set 5 | corn island
# Processing Record 3 of Set 5 | sitka
# Processing Record 4 of Set 5 | jalu
# Processing Record 5 of Set 5 | taksimo
# Processing Record 6 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 7 of Set 5 | fortuna
# Processing Record 8 of Set 5 | norman wells
# Processing Record 9 of Set 5 | manggar
# Processing Record 10 of Set 5 | chulym
# Processing Record 11 of Set 5 | sao bernardo
# Processing Record 12 of Set 5 | port hardy
# Processing Record 13 of Set 5 | nouadhibou
# Processing Record 14 of Set 5 | severo-kurilsk
# Processing Record 15 of Set 5 | sambava
# Processing Record 16 of Set 5 | wasilla
# Processing Record 17 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 5 | nanakuli
# Processing Record 19 of Set 5 | longyearbyen
# Processing Record 20 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 21 of Set 5 | yonago
# Processing Record 22 of Set 5 | rabak
# Processing Record 23 of Set 5 | udachnyy
# Processing Record 24 of Set 5 | mugur-aksy
# Processing Record 25 of Set 5 | subang
# Processing Record 26 of Set 5 | sakaiminato
# Processing Record 27 of Set 5 | saint-francois
# Processing Record 28 of Set 5 | port said
# Processing Record 29 of Set 5 | bintulu
# Processing Record 30 of Set 5 | guadalupe y calvo
# Processing Record 31 of Set 5 | bulawayo
# Processing Record 32 of Set 5 | nemuro
# Processing Record 33 of Set 5 | nabire
# Processing Record 34 of Set 5 | moengo
# Processing Record 35 of Set 5 | khatanga
# Processing Record 36 of Set 5 | springfield
# Processing Record 37 of Set 5 | mulchen
# Processing Record 38 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 5 | college
# Processing Record 40 of Set 5 | ulaanbaatar
# Processing Record 41 of Set 5 | pathein
# Processing Record 42 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 5 | conakry
# Processing Record 45 of Set 5 | san-pedro
# Processing Record 46 of Set 5 | dharchula
# Processing Record 47 of Set 5 | jamestown
# Processing Record 48 of Set 5 | vila velha
# Processing Record 49 of Set 5 | palmas de monte alto
# Processing Record 50 of Set 5 | codrington
# Processing Record 1 of Set 6 | waitati
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | dingle
# Processing Record 4 of Set 6 | eureka
# Processing Record 5 of Set 6 | akropong
# Processing Record 6 of Set 6 | tasiilaq
# Processing Record 7 of Set 6 | wald-michelbach
# Processing Record 8 of Set 6 | chama
# Processing Record 9 of Set 6 | mitchell
# Processing Record 10 of Set 6 | koraput
# Processing Record 11 of Set 6 | rioblanco
# Processing Record 12 of Set 6 | dubbo
# Processing Record 13 of Set 6 | vao
# Processing Record 14 of Set 6 | carutapera
# Processing Record 15 of Set 6 | soller
# Processing Record 16 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 17 of Set 6 | husavik
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | bushehr
# Processing Record 20 of Set 6 | verkhoyansk
# Processing Record 21 of Set 6 | sabha
# Processing Record 22 of Set 6 | carmagnola
# Processing Record 23 of Set 6 | puerto carreno
# Processing Record 24 of Set 6 | ogaminana
# Processing Record 25 of Set 6 | puerto baquerizo moreno
# Processing Record 26 of Set 6 | kavaratti
# Processing Record 27 of Set 6 | teknaf
# Processing Record 28 of Set 6 | jandayan
# Processing Record 29 of Set 6 | walvis bay
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | mehamn
# Processing Record 32 of Set 6 | assare
# Processing Record 33 of Set 6 | namibe
# Processing Record 34 of Set 6 | gizo
# Processing Record 35 of Set 6 | shanhetun
# Processing Record 36 of Set 6 | wajima
# Processing Record 37 of Set 6 | mookane
# Processing Record 38 of Set 6 | champerico
# Processing Record 39 of Set 6 | khorramshahr
# Processing Record 40 of Set 6 | porvoo
# Processing Record 41 of Set 6 | karratha
# Processing Record 42 of Set 6 | marsh harbour
# Processing Record 43 of Set 6 | kununurra
# Processing Record 44 of Set 6 | sovetskiy
# Processing Record 45 of Set 6 | port elizabeth
# Processing Record 46 of Set 6 | nurobod
# Processing Record 47 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 6 | surt
# Processing Record 1 of Set 7 | koumac
# Processing Record 2 of Set 7 | kasongo
# Processing Record 3 of Set 7 | gobabis
# Processing Record 4 of Set 7 | dzaoudzi
# Processing Record 5 of Set 7 | yaguacire
# Processing Record 6 of Set 7 | vila franca do campo
# Processing Record 7 of Set 7 | healdsburg
# Processing Record 8 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 7 | daru
# Processing Record 10 of Set 7 | mount gambier
# Processing Record 11 of Set 7 | ostrovnoy
# Processing Record 12 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 7 | syamzha
# Processing Record 14 of Set 7 | north bend
# Processing Record 15 of Set 7 | zhigansk
# Processing Record 16 of Set 7 | cabo san lucas
# Processing Record 17 of Set 7 | los llanos de aridane
# Processing Record 18 of Set 7 | mount isa
# Processing Record 19 of Set 7 | mutis
# Processing Record 20 of Set 7 | balkanabat
# Processing Record 21 of Set 7 | morro bay
# Processing Record 22 of Set 7 | olavarria
# Processing Record 23 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 7 | rossland
# Processing Record 25 of Set 7 | kieta
# Processing Record 26 of Set 7 | maldonado
# Processing Record 27 of Set 7 | guiratinga
# Processing Record 28 of Set 7 | biak
# Processing Record 29 of Set 7 | georgiyevka
# Processing Record 30 of Set 7 | salalah
# Processing Record 31 of Set 7 | ituango
# Processing Record 32 of Set 7 | shubarshi
# Processing Record 33 of Set 7 | kankan
# Processing Record 34 of Set 7 | araouane
# Processing Record 35 of Set 7 | rock springs
# Processing Record 36 of Set 7 | haicheng
# Processing Record 37 of Set 7 | kahului
# Processing Record 38 of Set 7 | wahlstedt
# Processing Record 39 of Set 7 | ambilobe
# Processing Record 40 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 7 | virginia beach
# Processing Record 42 of Set 7 | deneysville
# Processing Record 43 of Set 7 | clyde river
# Processing Record 44 of Set 7 | lianzhou
# Processing Record 45 of Set 7 | mariakani
# Processing Record 46 of Set 7 | srednekolymsk
# Processing Record 47 of Set 7 | evensk
# Processing Record 48 of Set 7 | bardiyah
# Processing Record 49 of Set 7 | yeppoon
# Processing Record 50 of Set 7 | mitsamiouli
# Processing Record 1 of Set 8 | verdalsora
# City not found. Skipping...
# Processing Record 2 of Set 8 | muncar
# Processing Record 3 of Set 8 | kilindoni
# Processing Record 4 of Set 8 | vagay
# Processing Record 5 of Set 8 | belmonte
# Processing Record 6 of Set 8 | adrar
# Processing Record 7 of Set 8 | portales
# Processing Record 8 of Set 8 | porbandar
# Processing Record 9 of Set 8 | aswan
# Processing Record 10 of Set 8 | nyrob
# Processing Record 11 of Set 8 | ignatovka
# Processing Record 12 of Set 8 | barra do garcas
# Processing Record 13 of Set 8 | inuvik
# Processing Record 14 of Set 8 | mingoyo
# Processing Record 15 of Set 8 | sur
# Processing Record 16 of Set 8 | brookings
# Processing Record 17 of Set 8 | russell
# Processing Record 18 of Set 8 | merke
# Processing Record 19 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 8 | laguna
# Processing Record 21 of Set 8 | yenagoa
# Processing Record 22 of Set 8 | naze
# Processing Record 23 of Set 8 | lahaina
# Processing Record 24 of Set 8 | avera
# Processing Record 25 of Set 8 | estevan
# Processing Record 26 of Set 8 | uaua
# Processing Record 27 of Set 8 | lasa
# Processing Record 28 of Set 8 | pevek
# Processing Record 29 of Set 8 | grand-santi
# Processing Record 30 of Set 8 | anloga
# Processing Record 31 of Set 8 | kolokani
# Processing Record 32 of Set 8 | shache
# Processing Record 33 of Set 8 | glendive
# Processing Record 34 of Set 8 | tobermory
# Processing Record 35 of Set 8 | nome
# Processing Record 36 of Set 8 | giyani
# Processing Record 37 of Set 8 | prince rupert
# Processing Record 38 of Set 8 | kribi
# Processing Record 39 of Set 8 | leh
# Processing Record 40 of Set 8 | hervey bay
# Processing Record 41 of Set 8 | shenjiamen
# Processing Record 42 of Set 8 | menongue
# Processing Record 43 of Set 8 | vestmannaeyjar
# Processing Record 44 of Set 8 | beian
# Processing Record 45 of Set 8 | nanortalik
# Processing Record 46 of Set 8 | muros
# Processing Record 47 of Set 8 | sindor
# Processing Record 48 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 8 | la ronge
# Processing Record 50 of Set 8 | warrnambool
# Processing Record 1 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 2 of Set 9 | jinji
# Processing Record 3 of Set 9 | margate
# Processing Record 4 of Set 9 | trincomalee
# Processing Record 5 of Set 9 | yaan
# Processing Record 6 of Set 9 | kampot
# Processing Record 7 of Set 9 | talas
# Processing Record 8 of Set 9 | mogadishu
# Processing Record 9 of Set 9 | general roca
# Processing Record 10 of Set 9 | methoni
# Processing Record 11 of Set 9 | saratoga springs
# Processing Record 12 of Set 9 | marsa matruh
# Processing Record 13 of Set 9 | arantangi
# Processing Record 14 of Set 9 | noumea
# Processing Record 15 of Set 9 | proletariy
# Processing Record 16 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 9 | bellevue
# Processing Record 18 of Set 9 | khipro
# Processing Record 19 of Set 9 | biltine
# Processing Record 20 of Set 9 | puerto madryn
# Processing Record 21 of Set 9 | aklavik
# Processing Record 22 of Set 9 | mahibadhoo
# Processing Record 23 of Set 9 | tautira
# Processing Record 24 of Set 9 | tirumala
# Processing Record 25 of Set 9 | hovd
# Processing Record 26 of Set 9 | isangel
# Processing Record 27 of Set 9 | media luna
# Processing Record 28 of Set 9 | bubaque
# Processing Record 29 of Set 9 | raudeberg
# Processing Record 30 of Set 9 | sosnovka
# Processing Record 31 of Set 9 | along
# Processing Record 32 of Set 9 | steinbach
# Processing Record 33 of Set 9 | iqaluit
# Processing Record 34 of Set 9 | rottingdean
# Processing Record 35 of Set 9 | sarakhs
# Processing Record 36 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 37 of Set 9 | gogrial
# Processing Record 38 of Set 9 | balingen
# Processing Record 39 of Set 9 | polovinnoye
# Processing Record 40 of Set 9 | sobolevo
# Processing Record 41 of Set 9 | moranbah
# Processing Record 42 of Set 9 | ossora
# Processing Record 43 of Set 9 | nelson bay
# Processing Record 44 of Set 9 | abu kamal
# Processing Record 45 of Set 9 | manavalakurichi
# Processing Record 46 of Set 9 | luau
# Processing Record 47 of Set 9 | san jose
# Processing Record 48 of Set 9 | skibbereen
# Processing Record 49 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 9 | yerbogachen
# Processing Record 1 of Set 10 | junin
# Processing Record 2 of Set 10 | camrose
# Processing Record 3 of Set 10 | machinga
# Processing Record 4 of Set 10 | ukiah
# Processing Record 5 of Set 10 | thai binh
# Processing Record 6 of Set 10 | ati
# Processing Record 7 of Set 10 | skala
# Processing Record 8 of Set 10 | yumen
# Processing Record 9 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 10 | duldurga
# Processing Record 11 of Set 10 | rawson
# Processing Record 12 of Set 10 | burley
# Processing Record 13 of Set 10 | paamiut
# Processing Record 14 of Set 10 | toronto
# Processing Record 15 of Set 10 | baiyin
# Processing Record 16 of Set 10 | baykit
# Processing Record 17 of Set 10 | saint-prosper
# Processing Record 18 of Set 10 | karjat
# Processing Record 19 of Set 10 | amahai
# Processing Record 20 of Set 10 | vadgaon
# Processing Record 21 of Set 10 | quelimane
# Processing Record 22 of Set 10 | halifax
# Processing Record 23 of Set 10 | morros
# Processing Record 24 of Set 10 | santa cruz
# Processing Record 25 of Set 10 | malazgirt
# Processing Record 26 of Set 10 | asmara
# Processing Record 27 of Set 10 | alice springs
# Processing Record 28 of Set 10 | katherine
# Processing Record 29 of Set 10 | istria
# Processing Record 30 of Set 10 | ocos
# Processing Record 31 of Set 10 | neiafu
# Processing Record 32 of Set 10 | karangampel
# Processing Record 33 of Set 10 | sao jose da coroa grande
# Processing Record 34 of Set 10 | bonavista
# Processing Record 35 of Set 10 | calama
# Processing Record 36 of Set 10 | kagadi
# Processing Record 37 of Set 10 | hereford
# Processing Record 38 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 10 | halaszi
# Processing Record 40 of Set 10 | coquimbo
# Processing Record 41 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 42 of Set 10 | vostok
# Processing Record 43 of Set 10 | shahr-e kord
# Processing Record 44 of Set 10 | teguise
# Processing Record 45 of Set 10 | cootamundra
# Processing Record 46 of Set 10 | hambantota
# Processing Record 47 of Set 10 | mgandu
# Processing Record 48 of Set 10 | redondela
# Processing Record 49 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 50 of Set 10 | afua
# Processing Record 1 of Set 11 | meulaboh
# Processing Record 2 of Set 11 | okakarara
# Processing Record 3 of Set 11 | takoradi
# Processing Record 4 of Set 11 | qasigiannguit
# Processing Record 5 of Set 11 | tokur
# Processing Record 6 of Set 11 | namatanai
# Processing Record 7 of Set 11 | vilyuysk
# Processing Record 8 of Set 11 | alyangula
# Processing Record 9 of Set 11 | manono
# Processing Record 10 of Set 11 | beyneu
# Processing Record 11 of Set 11 | topolog
# Processing Record 12 of Set 11 | stornoway
# Processing Record 13 of Set 11 | okaihau
# Processing Record 14 of Set 11 | point fortin
# Processing Record 15 of Set 11 | tonekabon
# Processing Record 16 of Set 11 | half moon bay
# Processing Record 17 of Set 11 | qena
# Processing Record 18 of Set 11 | the hammocks
# Processing Record 19 of Set 11 | la orilla
# Processing Record 20 of Set 11 | rocha
# Processing Record 21 of Set 11 | cairns
# Processing Record 22 of Set 11 | rio real
# Processing Record 23 of Set 11 | sao joao da barra
# Processing Record 24 of Set 11 | wagar
# Processing Record 25 of Set 11 | filadelfia
# Processing Record 26 of Set 11 | pisco
# Processing Record 27 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 29 of Set 11 | koygorodok
# Processing Record 30 of Set 11 | goalpara
# Processing Record 31 of Set 11 | christchurch
# Processing Record 32 of Set 11 | saint-augustin
# Processing Record 33 of Set 11 | nieves
# Processing Record 34 of Set 11 | charlestown
# Processing Record 35 of Set 11 | barquisimeto
# Processing Record 36 of Set 11 | sabang
# Processing Record 37 of Set 11 | bereda
# Processing Record 38 of Set 11 | ibra
# Processing Record 39 of Set 11 | kamaishi
# Processing Record 40 of Set 11 | imeni poliny osipenko
# Processing Record 41 of Set 11 | havre-saint-pierre
# Processing Record 42 of Set 11 | bafq
# Processing Record 43 of Set 11 | xai-xai
# Processing Record 44 of Set 11 | camacupa
# Processing Record 45 of Set 11 | beloha
# Processing Record 46 of Set 11 | bileca
# Processing Record 47 of Set 11 | tari
# Processing Record 48 of Set 11 | kendari
# Processing Record 49 of Set 11 | atasu
# Processing Record 50 of Set 11 | ramhormoz
# Processing Record 1 of Set 12 | hay river
# Processing Record 2 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 3 of Set 12 | taybad
# Processing Record 4 of Set 12 | tateyama
# Processing Record 5 of Set 12 | bull savanna
# Processing Record 6 of Set 12 | alanya
# Processing Record 7 of Set 12 | kinablangan
# Processing Record 8 of Set 12 | buturlino
# Processing Record 9 of Set 12 | katangli
# Processing Record 10 of Set 12 | roma
# Processing Record 11 of Set 12 | maceio
# Processing Record 12 of Set 12 | taoudenni
# Processing Record 13 of Set 12 | krasnoselkup
# Processing Record 14 of Set 12 | ewa beach
# Processing Record 15 of Set 12 | riyadh
# Processing Record 16 of Set 12 | byumba
# Processing Record 17 of Set 12 | tottori
# Processing Record 18 of Set 12 | san bartolome de tirajana
# Processing Record 19 of Set 12 | nyurba
# Processing Record 20 of Set 12 | panzhihua
# Processing Record 21 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 12 | chicama
# Processing Record 23 of Set 12 | guhagar
# Processing Record 24 of Set 12 | deputatskiy
# Processing Record 25 of Set 12 | wa
# City not found. Skipping...
# Processing Record 26 of Set 12 | gamba
# Processing Record 27 of Set 12 | matata
# Processing Record 28 of Set 12 | naliya
# Processing Record 29 of Set 12 | powell river
# Processing Record 30 of Set 12 | ravar
# Processing Record 31 of Set 12 | najran
# Processing Record 32 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 34 of Set 12 | yulara
# Processing Record 35 of Set 12 | nalut
# Processing Record 36 of Set 12 | jijiang
# Processing Record 37 of Set 12 | kosh-agach
# Processing Record 38 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 39 of Set 12 | pinotepa nacional
# Processing Record 40 of Set 12 | vysokogornyy
# Processing Record 41 of Set 12 | olbia
# Processing Record 42 of Set 12 | sinnamary
# Processing Record 43 of Set 12 | poronaysk
# Processing Record 44 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 12 | norden
# Processing Record 46 of Set 12 | sagua la grande
# Processing Record 47 of Set 12 | leningradskiy
# Processing Record 48 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 12 | freeport
# Processing Record 50 of Set 12 | karamken
# City not found. Skipping...
# Processing Record 1 of Set 13 | aksha
# Processing Record 2 of Set 13 | khadyzhensk
# Processing Record 3 of Set 13 | buala
# Processing Record 4 of Set 13 | te anau
# Processing Record 5 of Set 13 | sunam
# Processing Record 6 of Set 13 | paris
# Processing Record 7 of Set 13 | rayon
# Processing Record 8 of Set 13 | marovoay
# Processing Record 9 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 10 of Set 13 | nisia floresta
# Processing Record 11 of Set 13 | praia
# Processing Record 12 of Set 13 | bac lieu
# Processing Record 13 of Set 13 | qandahar
# City not found. Skipping...
# Processing Record 14 of Set 13 | medea
# Processing Record 15 of Set 13 | camana
# Processing Record 16 of Set 13 | bollnas
# Processing Record 17 of Set 13 | bulungu
# Processing Record 18 of Set 13 | archidona
# Processing Record 19 of Set 13 | umm lajj
# Processing Record 20 of Set 13 | umarkot
# Processing Record 21 of Set 13 | mocuba
# Processing Record 22 of Set 13 | sug-aksy
# City not found. Skipping...
# Processing Record 23 of Set 13 | port hedland
# Processing Record 24 of Set 13 | caxito
# Processing Record 25 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 26 of Set 13 | vondrozo
# Processing Record 27 of Set 13 | conceicao do araguaia
# Processing Record 28 of Set 13 | falun
# Processing Record 29 of Set 13 | gat
# Processing Record 30 of Set 13 | taft
# Processing Record 31 of Set 13 | conde
# Processing Record 32 of Set 13 | mandalgovi
# Processing Record 33 of Set 13 | honningsvag
# Processing Record 34 of Set 13 | tiszakarad
# Processing Record 35 of Set 13 | kaolinovo
# Processing Record 36 of Set 13 | salym
# Processing Record 37 of Set 13 | rio grande
# Processing Record 38 of Set 13 | bahia blanca
# Processing Record 39 of Set 13 | de aar
# Processing Record 40 of Set 13 | tekeli
# Processing Record 41 of Set 13 | vanavara
# Processing Record 42 of Set 13 | seoul
# Processing Record 43 of Set 13 | grand gaube
# Processing Record 44 of Set 13 | dicabisagan
# Processing Record 45 of Set 13 | mach
# Processing Record 46 of Set 13 | malakal
# Processing Record 47 of Set 13 | fez
# Processing Record 48 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 49 of Set 13 | batouri
# Processing Record 50 of Set 13 | trairi
# Processing Record 1 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 14 | east haven
# Processing Record 3 of Set 14 | waipawa
# Processing Record 4 of Set 14 | sangar
# Processing Record 5 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 14 | murgab
# Processing Record 7 of Set 14 | abeche
# Processing Record 8 of Set 14 | brainerd
# Processing Record 9 of Set 14 | rincon
# Processing Record 10 of Set 14 | otane
# Processing Record 11 of Set 14 | navirai
# Processing Record 12 of Set 14 | masuda
# Processing Record 13 of Set 14 | babushkin
# Processing Record 14 of Set 14 | westport
# Processing Record 15 of Set 14 | itoman
# Processing Record 16 of Set 14 | santa lucia
# Processing Record 17 of Set 14 | zdvinsk
# Processing Record 18 of Set 14 | borovoy
# Processing Record 19 of Set 14 | abnub
# Processing Record 20 of Set 14 | uxbridge
# Processing Record 21 of Set 14 | sakakah
# Processing Record 22 of Set 14 | awbari
# Processing Record 23 of Set 14 | puerto quijarro
# Processing Record 24 of Set 14 | arrecife
# Processing Record 25 of Set 14 | kaeo
# Processing Record 26 of Set 14 | santa engracia
# Processing Record 27 of Set 14 | chiredzi
# Processing Record 28 of Set 14 | egvekinot
# Processing Record 29 of Set 14 | milkovo
# Processing Record 30 of Set 14 | ruteng
# Processing Record 31 of Set 14 | lomovka
# Processing Record 32 of Set 14 | manyana
# Processing Record 33 of Set 14 | gorele
# Processing Record 34 of Set 14 | bloomington
# Processing Record 35 of Set 14 | palasbari
# Processing Record 36 of Set 14 | opuwo
# Processing Record 37 of Set 14 | oranjemund
# Processing Record 38 of Set 14 | diffa
# Processing Record 39 of Set 14 | birjand
# Processing Record 40 of Set 14 | tuatapere
# Processing Record 41 of Set 14 | korla
# Processing Record 42 of Set 14 | aguada de pasajeros
# Processing Record 43 of Set 14 | dalbandin
# Processing Record 44 of Set 14 | jishou
# Processing Record 45 of Set 14 | bosanski brod
# Processing Record 46 of Set 14 | kristiinankaupunki
# Processing Record 47 of Set 14 | limulunga
# Processing Record 48 of Set 14 | yar-sale
# Processing Record 49 of Set 14 | kouvola
# Processing Record 50 of Set 14 | ketchikan
# Processing Record 1 of Set 15 | ca mau
# Processing Record 2 of Set 15 | yantal
# Processing Record 3 of Set 15 | shipunovo
# Processing Record 4 of Set 15 | puli
# Processing Record 5 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 15 | manjakandriana
# Processing Record 7 of Set 15 | bandarbeyla
# Processing Record 8 of Set 15 | price
# Processing Record 9 of Set 15 | ulundi
# Processing Record 10 of Set 15 | aguimes
# Processing Record 11 of Set 15 | mzimba
# Processing Record 12 of Set 15 | eyl
# Processing Record 13 of Set 15 | the pas
# Processing Record 14 of Set 15 | lakes entrance
# Processing Record 15 of Set 15 | broome
# Processing Record 16 of Set 15 | balykshi
# Processing Record 17 of Set 15 | flin flon
# Processing Record 18 of Set 15 | camacha
# Processing Record 19 of Set 15 | lavrentiya
# Processing Record 20 of Set 15 | pyaozerskiy
# Processing Record 21 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 15 | sukhaya buyvola
# Processing Record 23 of Set 15 | burica
# City not found. Skipping...
# Processing Record 24 of Set 15 | concepcion del oro
# Processing Record 25 of Set 15 | mayor pablo lagerenza
# Processing Record 26 of Set 15 | sanok
# Processing Record 27 of Set 15 | mercedes
# Processing Record 28 of Set 15 | deniliquin
# Processing Record 29 of Set 15 | boone
# Processing Record 30 of Set 15 | warmbad
# Processing Record 31 of Set 15 | ardakan
# Processing Record 32 of Set 15 | bar harbor
# Processing Record 33 of Set 15 | mukilteo
# Processing Record 34 of Set 15 | moron
# Processing Record 35 of Set 15 | ust-tsilma
# Processing Record 36 of Set 15 | bodden town
# Processing Record 37 of Set 15 | hoi an
# Processing Record 38 of Set 15 | graaff-reinet
# Processing Record 39 of Set 15 | franca
# Processing Record 40 of Set 15 | quatre cocos
# Processing Record 41 of Set 15 | lazaro cardenas
# Processing Record 42 of Set 15 | taguatinga
# Processing Record 43 of Set 15 | longview
# Processing Record 44 of Set 15 | rensvik
# Processing Record 45 of Set 15 | cavalcante
# Processing Record 46 of Set 15 | ust-uda
# Processing Record 47 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 48 of Set 15 | hattiesburg
# Processing Record 49 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 15 | mazamet
# Processing Record 1 of Set 16 | samarai
# Processing Record 2 of Set 16 | metro
# Processing Record 3 of Set 16 | manta
# Processing Record 4 of Set 16 | mayo
# Processing Record 5 of Set 16 | alekseyevka
# Processing Record 6 of Set 16 | flinders
# Processing Record 7 of Set 16 | tilichiki
# Processing Record 8 of Set 16 | betsiamites
# Processing Record 9 of Set 16 | yialos
# City not found. Skipping...
# Processing Record 10 of Set 16 | vardo
# Processing Record 11 of Set 16 | guayaramerin
# Processing Record 12 of Set 16 | terme
# Processing Record 13 of Set 16 | barra do bugres
# Processing Record 14 of Set 16 | beboto
# Processing Record 15 of Set 16 | kursavka
# Processing Record 16 of Set 16 | promysla
# City not found. Skipping...
# Processing Record 17 of Set 16 | khovu-aksy
# Processing Record 18 of Set 16 | lanzhou
# Processing Record 19 of Set 16 | ongandjera
# Processing Record 20 of Set 16 | boali
# Processing Record 21 of Set 16 | santa luzia
# Processing Record 22 of Set 16 | southbridge
# Processing Record 23 of Set 16 | chifeng
# Processing Record 24 of Set 16 | salo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Butaritari   3.0707  172.7902     80.96        76          60
# 1          Narsaq  60.9167  -46.0500     55.40        15          20
# 2  Ribeira Grande  38.5167  -28.7000     64.40        94          75
# 3           Airai  -8.9266  125.4092     57.94        88          72
# 4           Vaini -21.2000 -175.2000     66.20        94          20
# 5      Alexandria  31.2156   29.9553     60.80        51          20
# 6           Ancud -41.8697  -73.8203     59.00       100          90
# 7     Provideniya  64.3833 -173.3000      9.09        85         100
# 8           Orlik  52.5178   99.8250     14.79        71          39
# 9      Sao Filipe  14.8961  -24.4956     76.24        63           1
#
#    Wind Speed Country Current Description
# 0        8.77      KI          light rain
# 1       20.71      GL          few clouds
# 2        5.75      PT       broken clouds
# 3        1.63      TL       broken clouds
# 4        3.44      TO          few clouds
# 5       14.97      EG          few clouds
# 6       14.97      CL          light rain
# 7       23.15      RU          light snow
# 8        4.05      RU    scattered clouds
# 9        5.66      CV           clear sky

# %%
new_column_order= ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Butaritari      KI   3.0707  172.7902     80.96        76
# 1            Narsaq      GL  60.9167  -46.0500     55.40        15
# 2    Ribeira Grande      PT  38.5167  -28.7000     64.40        94
# 3             Airai      TL  -8.9266  125.4092     57.94        88
# 4             Vaini      TO -21.2000 -175.2000     66.20        94
# ..              ...     ...      ...       ...       ...       ...
# 710           Boali      CF   4.8005   18.1275     89.60        55
# 711     Santa Luzia      BR -19.7697  -43.8514     82.40        44
# 712     Southbridge      US  42.0751  -72.0334     57.99        68
# 713         Chifeng      CN  42.2683  118.9636     48.74        56
# 714            Salo      IT  45.6086   10.5310     52.00        82
#
#      Cloudiness  Wind Speed Current Description
# 0            60        8.77          light rain
# 1            20       20.71          few clouds
# 2            75        5.75       broken clouds
# 3            72        1.63       broken clouds
# 4            20        3.44          few clouds
# ..          ...         ...                 ...
# 710          20        6.91          few clouds
# 711           0        5.75           clear sky
# 712         100        1.99     overcast clouds
# 713          67       10.31       broken clouds
# 714          90        4.61     overcast clouds
#
# [715 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
